# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline , make_pipeline
from sklearn.tree import DecisionTreeClassifier
import joblib

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Documents\Presentation_mini\car_customers web.csv")
data
# Out:
#    CarModel   BodyType Manufacturer FuelType  SafetyRating    Price   Budget  \
# 0     Sonet        SUV          Kia   Diesel             4  1050000  1089469
# 1    Seltos        SUV          Kia   Diesel             5  1200000  1393898
# 2    XUV700        SUV     Mahindra   Diesel             5  2300000  2737140
# 3      City      Sedan        Honda   Petrol             5  1200000  1073712
# 4      Kwid  Hatchback      Renault   Petrol             3   450000   405385
# ..      ...        ...          ...      ...           ...      ...      ...
# 71   Brezza        SUV       Maruti   Petrol             4   950000   900721
# 72    Venue        SUV      Hyundai   Petrol             4   900000   977738
# 73   Baleno  Hatchback       Maruti   Petrol             4   800000   869082
# 74     City      Sedan        Honda   Petrol             5  1200000  1024450
# 75     Jazz  Hatchback        Honda   Petrol             4   800000   872622
#
#               DesiredFeatures  Age  FamilySize  Purchased
# 0   Infotainment, Rear Camera   35           6          1
# 1       Sunroof, Infotainment   37           4          1
# 2               ADAS, Sunroof   37           7          1
# 3                Sunroof, ABS   37           4          1
# 4                         ABS   31           2          0
# ..                        ...  ...         ...        ...
# 71                        ABS   39           3          1
# 72               Infotainment   33           3          0
# 73          Infotainment, ABS   30           2          0
# 74               Sunroof, ABS   32           6          1
# 75               Infotainment   33           4          0
#
# [76 rows x 11 columns]

# %%
x = data.drop(["CarModel","Price","Purchased"], axis=1)
x
# Out:
#      BodyType Manufacturer FuelType  SafetyRating   Budget  \
# 0         SUV          Kia   Diesel             4  1089469
# 1         SUV          Kia   Diesel             5  1393898
# 2         SUV     Mahindra   Diesel             5  2737140
# 3       Sedan        Honda   Petrol             5  1073712
# 4   Hatchback      Renault   Petrol             3   405385
# ..        ...          ...      ...           ...      ...
# 71        SUV       Maruti   Petrol             4   900721
# 72        SUV      Hyundai   Petrol             4   977738
# 73  Hatchback       Maruti   Petrol             4   869082
# 74      Sedan        Honda   Petrol             5  1024450
# 75  Hatchback        Honda   Petrol             4   872622
#
#               DesiredFeatures  Age  FamilySize
# 0   Infotainment, Rear Camera   35           6
# 1       Sunroof, Infotainment   37           4
# 2               ADAS, Sunroof   37           7
# 3                Sunroof, ABS   37           4
# 4                         ABS   31           2
# ..                        ...  ...         ...
# 71                        ABS   39           3
# 72               Infotainment   33           3
# 73          Infotainment, ABS   30           2
# 74               Sunroof, ABS   32           6
# 75               Infotainment   33           4
#
# [76 rows x 8 columns]

# %%
y = data['CarModel']
y
# Out:
# 0      Sonet
# 1     Seltos
# 2     XUV700
# 3       City
# 4       Kwid
#        ...
# 71    Brezza
# 72     Venue
# 73    Baleno
# 74      City
# 75      Jazz
# Name: CarModel, Length: 76, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
 # Categorical and Numerical Columns
categorical_cols = ['BodyType', 'Manufacturer', 'FuelType', 'DesiredFeatures']
numerical_cols = ['SafetyRating', 'Budget', 'Age', 'FamilySize']

# %%
preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ('num', 'passthrough', numerical_cols)
    ])

# %%
model_pipeline = make_pipeline(preprocessor, DecisionTreeClassifier(random_state=42))

# %%
model_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['BodyType', 'Manufacturer',
#                                                    'FuelType',
#                                                    'DesiredFeatures']),
#                                                  ('num', 'passthrough',
#                                                   ['SafetyRating', 'Budget',
#                                                    'Age', 'FamilySize'])])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(random_state=42))])

# %%
joblib.dump(model_pipeline, 'car_model_pipeline.joblib')
print("Model trained and saved successfully!")
# Out:
# Model trained and saved successfully!
